# %% [markdown]
# # AdWords Display Basics, Part I

# %% [markdown]
# ### Learn the basics of AdWords
# - AdWords is an online advertising tool that helps businesses connect with their customers. You create your online ad, tell AdWords who you want to reach, and AdWords brings your ads to them. That’s basically it.
# - Benefits of AdWords
#     - AdWords has a sophisticated targeting system that helps you show your ads to the right people, in the right place, at the right time. Use keywords, location, demographics, and more to target your campaigns.
#     - AdWords gives you complete control over your budget. You choose how much you spend per month, per day, and per ad. There’s no minimum.
#     - AdWords shows you how many people see your ads, what percentage of them click to visit your website, and even how many click to call you. With these tracking tools, you can even see the actual sales your website is generating as a direct result of your ads.

# %% [markdown]
# ### Choose where customers see your ads
# -  The Google Network is made up of two networks: Search and Display. They're the places where your AdWords ads can appear, including: Google sites, partner sites, and other placements like mobile phone apps.
# - On the Search Network, your ads may appear on:
#      - Google Search, Google Shopping, Google Maps, and Google Play.
#      - Search sites that partner with Google.
# - On the Display Network, your ads may appear on:
#      - Google sites like YouTube, Blogger, and Gmail.
#      - Partnering websites across the internet.
#
# - The Google Network can connect you with customers at the exact moment they're engaged in an online activity connected to what you offer — like searching for your product, reading a blog about your industry, or watching a related video on YouTube. Choosing the correct ad format for your campaign can ensure your ad is the most relevant and actionable for a particular customer at that moment.
#
# - Ads Format
#     - **Text Ads**: The most common kind of Search ad includes a descriptive headline, website URL, and descriptive text like a call to action.
#         - Search Network
#         - Search Partners
#     - **Ads with extensions**: Ad extensions provide additional information to your text ad, such as your business’s address or phone number.
#         - Search Network
#         - Display Network (depending on the extension)
#     - **Responsive ads**: The Display Network offers ads that adjust to match the pages and apps that show them. Viewers are more likely to see these ads because they blend in with the content the viewers came for. Responsive ads can go a long way to help build awareness, influence consideration, and drive action.
#         - Display Network
#     - **Shopping ads**: In addition to an image, Shopping ads contain product and pricing information, so users get a strong sense of the product you're selling before they click your ad. They’re ideal if you’re managing a large inventory of products.
#         - Google Shopping (in select countries)
#         - Google Search
#         - Google Search Partner websites, including YouTube and Image Search in some countries (if your campaign is set to include search partners)
#     - **Image ads**: Image ads capture people's attention as they browse websites in the Google Display Network.
#         - Search Network - *Image ads show on search partner networks, but not the Google Search Network.*
#         - Display Network
#     - **Video ads**: Video ads are just what they sound like — a standalone video ad or a video ad that runs inside another streaming video.
#         - Search Network - *Image ads show on search partner networks, but not the Google Search Network.*
#         - Display Network
#     - **Add Promotional ads**: App promotion ads send your customers to an app store to download your app, or include a deep link directly into your app.
#         - Search Network
#         - Display Network
#     - **Call-only ads**: Call-only ads allow your customers to call your business directly by clicking on your ad. They’re useful for driving phone calls to your business from devices that can make calls.
#         - Search Network
#     - **Rich media ads**: Rich media ads are engaging ad formats that often include animation or other types of motion.
#         - Display Network

# %% [markdown]
# ### Learn the basics of the Display Network
# - **What is the Google Display Network?**
#     - Google’s Display Network is the largest display network in the world, including over two million websites and one million apps (including Gmail and YouTube).
# - **How does AdWords work with the Display Network?**
#     - The Display Network allows you to create various types of ads such as responsive, interactive, image, video and mobile ads, and show them to millions of new viewers across the web.
# - **Not sure where to start?**
#     - Display Network with Search Network by using Display Select. With the check of a box you can automatically expand into the Display Network and we will do the targeting for you based on the placements most likely to provide their same performance on search

# %% [markdown]
# ### Drive results with the Display Network
# - **Why use the Display Network?**
#     - Massive Scale: Run your ads and connect with your audience Gmail, YouTube, and millions of other sites.
#     - Measurable Performance and Maximized Results: Maximize results for both branding and direct display clients with the Display Network’s measurable performance.
#     - Contextual Engine: Google harnesses the best contextual engine on the planet to place ads against the most relevant content, driving your marketing results.
#     - Free tools for ad creation and campaign setup: AdWords provides free tools to help you create, measure, and optimize your ads for the Display Network
#     - Easy campaign setup with marketing objectives: You indicate your marketing objective and AdWords brings you only the features and options that are relevant to what you want to accomplish.
# - **Matching your campaign to your goals**
#     - BUILD AWARENESS: If you’re launching a new product or looking to expand, you’ll want to spread the word by getting a lot of people to ‘see your ad’ . The Display Network can help by getting your ads in front of lots of consumers.
#     - INFLUENCE CONSIDERATION: To stand out from competitors, you want to ensure your content catches the eye of the people who want what you offer. The Display Network can help with engaging ad formats and sophisticated targeting options.
#     - DRIVE ACTION: If you’re trying to get users to buy on your website, take an action on your website, call/visit your business or install your mobile app, you’ll want to target people who have previously engaged with your site or app, among other things.

# %% [markdown]
# ### Determine a good bidding strategy
# - Two ways of bidding:
#     - Manual bidding is where you control the bidding yourself. Automated, is where you let AdWords do the heavy lifting for you. Let’s take a closer look at each and then dig in on how to pick the best strategy for your business.
# - **Manual bidding**: Manual bidding lets you manually set bids at the ad group level, for individual keywords, or for ad placements, so you know you're bidding for the clicks that mean the most to you.
# - **Automated bidding**: With automated bidding you can set a daily budget and then have AdWords automatically adjust your bids to get the most clicks or conversions possible within your budget.
# - **Different Goals**:
#     - Goal: Build awareness. Focusing on impressions may be your strategy. You can use cost per thousand viewable impressions (vCPM) or cost per view (CPV) bidding to put your message in front of customers.
#     - Goal: Drive web visits. Focusing on clicks could be ideal for you. Cost-per-click (CPC) bidding—manual or automatic—may be right for your campaign.
#     - Goal: Drive online sales. It may be best to implement conversion tracking in your campaign and focus on conversions. Cost-per-acquisition (CPA) bidding lets you do just that.
# - Most people starting out in AdWords use cost-per-click (CPC) bidding. With this option, you set a maximum cost-per-click bid that's the highest amount you're willing to pay for a click on your ad. Set your bid by thinking about how much an ad click is worth to you. You can figure this out based on what you know about your business and the value of a sale.
# - **3 tools to determine your CPC bids:**
#     - **Bid simulator**: Bid simulator runs "what-if" scenarios like, How many more impressions would I have gotten if my bid had been 0.10 higher last week?
#     - **Keyword Planner**: Keyword Planner shows you how often some keywords get searched, and gives you cost estimates at a glance.
#     - **First-page bid estimates** First-page bid estimates helps you see how much you may need to bid to put your ad on the first page of Google search results.
# - What keywords lead to the most clicks on your ads?
#     - To see how many clicks you’re getting per keyword and how much they cost, go to the “keywords” tab in your account. Try filtering your keywords by click-through rate to see which keywords get you a lot of impressions, but few clicks. If your goal is to generate sales, these are the keywords that are probably not working so well.
# - How do I increase my ROI?
#      - Once you’ve identified which keywords, locations, times, and devices are getting good results, you can adjust your bids accordingly. For instance, if a keyword has a low average CPC but each click converts well, you may try increasing its max CPC bid. This could improve the ad’s average position for that keyword, giving your ads more exposure and potentially increasing your ROI.

# %% [markdown]
# ### Select your bid strategy
# - **How automated bidding works**
#     - Your keyword list determines which searches and site visits can trigger your ad if you win the bid, but the "right" bid for an impression can be a moving target influenced by things like match type, device, and location.
#     - With automated bidding, AdWords can automatically increase bids for impressions that it predicts (from auction-time data) could be more successful.
# - **When to use manual bidding**
#     - You don’t have enough conversions to meet the recommendations for automated bidding
#     - You need 100 percent control of how you pay for views, clicks or conversions
# - **How to choose your automated bidding strategy**
#     - Ad clicks: Maximize clicks automatically sets your bids to help get as many clicks as possible within your budget. It can increase site visits and increase clicks on low-traffic terms.
#     - Ad revenue: Target return-on-ad-spend (ROAS) bids more where AdWords estimates ads are more likely to lead to a sale — aiming to get as much return on ad spend as possible.
#     - Ad conversions: Automated bidding strategies designed to generate conversions include Enhanced cost per click (ECPC), Maximize conversions and Target cost per acquisition (CPA). We’ll dive into each of these in the following section.
# - **Which automated conversion bidding type is right for you?**
#     - **Enhanced cost per click (ECPC)** is a semi-automated bid strategy which adjusts your bids to get you as many conversions as possible, within your determined budget. You set keyword bids and let AdWords work its magic to improve your campaign’s performance. *Good for advertisers looking for an incremental increase in conversions while still retaining control over their keyword bids.*
#     - **Maximize conversions** bidding automatically sets bids at auction time to get you as much conversion volume as possible within your campaign’s budget. *Good for those with a fixed advertising budget already seeing at least 15 conversions and 15 clicks per month, who do not know how much they should be willing to pay for a conversion (in other words, they do not have a target CPA).*
#     - **Target CPA** automatically sets bids to help get as many conversions as possible at the target CPA you set (some conversions may cost more or less than your target). Target CPA does not operate within a set budget. *Good for advertisers who know how much they’re willing to pay for a conversion and prioritize maintaining a specific cost per conversion over driving conversion volume.*

# %% [markdown]
# ### Reach your customers with targeting
# - Find potential customers online
#     - One aspect of targeting focuses on “WHO” is in your target audience. Audience targeting helps you identify, re-engage, and expand your audience online. You can target those who actively intend to purchase your products and personalize your ads with relevant messages. All thanks to machine learning.
#     - Another aspect of targeting focuses on “WHERE” your audience is. “WHERE” can refer to where your customers are in the physical world (e.g., location and device targeting) or where they are online (e.g., contextual or topic targeting).
#     - The final aspect of targeting focuses on “WHAT” is of interest to your audience. With AdWords, you can specify keywords based on what people are searching for. When people search for words like your keywords on Google or partner sites, you can display your ads alongside those search results.

# %% [markdown]
# ### Target with the Display Network
# - **How can I target customers?**
#     - As you build your targeting, it’s important to keep in mind the stage in the purchasing funnel. You’ll want to consider whether you’re finding who your audience is or where it is you’re placing your ads.
#     - IMAGE: Google_ADs_1
# - **Drive action and conversions**
#     - Gmail ads: Find your best context
#         - Gmail ads are interactive ads at the top of people’s inboxes, which expand when clicked and can use images, video, or embedded forms. Gmail ads use automatic targeting to identify people’s interests. If you run a photography store, you might use keyword targeting to reach Gmail users who receive lots of emails about cameras. Or, you can use domain targeting to reach Gmail users who receive emails from popular photography websites.
#     - Automation: Find your best audience and context, automatically
#         - Bring the power of machine learning to your campaign with Smart display campaigns, which automate and then optimize targeting, bidding, and ads using the assets you provide.
#         - If you’re already running a Search Network campaign, you can also opt-in to the Display Network. This system automates targeting and bidding, enabling you to reach even more potential customers with minimal additional work.
# - **How can I connect with interested users?**
#     - Standard remarketing
#         - Show ads to your past visitors as they browse Display Network websites and use Display Network apps.
#     - Dynamic remarketing
#         - Work to boost your results with dynamic remarketing, which takes remarketing to the next level with ads that include products or services that people viewed on your website.
#     - Video remarketing
#         - Show ads to people who have interacted with your videos or YouTube channel as they use YouTube and browse Display Network videos, websites, and apps.
# - **Influence consideration**
#     - In-market audiences: Find your best audience
#         - Reach potential customers while they're actively browsing, researching or comparing the types of products you sell and are close to a conversion. Connect with those most interested in what you have to offer, using precise segments — things like "Skin care products", "Home theater systems" — that classify users based on their demonstrated in-market behavior and purchase intent.
#     - Content keyword targeting: Find your best audience
#         - You can target ads to people who are visiting or have visited websites with content relevant to keywords you enter. This is an easy way to target a lot of people who meet very narrow, specific criteria.
# - **Reach and awareness**
#     - Demographic targeting: Find your best audience
#          - Target prospective customers based on age, gender, parental status, region, language, and more.
#     - Affinity audiences: Find your best audience
#         - Reach audiences based on their specific interests as they browse pages, apps, channels, and content across the Display Network. Choose from 80 segments based on online behavior, including "Movie lovers”, "Foodies", "Sports fans", and more.
#     - Custom affinity targeting: Find your best audience
#         - Customize an existing affinity audience to further optimize and capture prospective customers. For example, rather than reaching sports fans, a running shoe company may want to reach “Avid marathon runners” instead. With custom affinity audiences, the shoe company can define this audience.
# - **Prospective customers**
#     - Reaching prospective customers, or those who are considering buying something from you, is vital. As you build your targeting around the purchasing funnel, it’s important to keep in mind getting customers into the funnel in the first place!
# - **Which targeting options should I use? **
#     - Build awareness
#         - Demographics, Affinity/custom affinity audiences
#     - Influence consideration
#         - In-market audiences, Audience keywords, Similar audiences
#     - Drive action
#         - Display remarketing
#     - Grow loyalty
#         - Display remarketing

# %% [markdown]
# ### Track conversions to improve performance
# - ** Conversion tracking recap**
#     - As explained in the video, conversion tracking helps advertisers track the impact of their ads so they can reinvest in the ads that generate the most interactions.
#     - The general process includes:
#         - The advertiser adding a snippet of code to certain spots on their website and app (like a sign up or checkout page) to capture interactions.
#         - When someone visits one of these places, the conversion tag fires capturing the user’s non personally identifiable ID.
#         - The ad server then takes a list of IDs and matches them against another list of IDs who have viewed or clicked an ad.
# - **Why use conversion tracking?**
#     - If you notice your “50% off” ad is driving more surfboard sales than your “Buy one - get one” ad, you can serve it more frequently.
#     - If you notice a certain demographic is more interested in signing up for surf lessons, you can shift your budget to target that audience.
#     - If you notice people are more interested in surf lessons on Fridays and buying a board on Mondays, you can schedule each creative to run on those specific days.

# %% [markdown]
# ### Keep them coming back with remarketing
# - **Remarketing recap**
#     - The general process includes:
#         - Adding tracking to your website or app to collect anonymous user data from visitors.
#         - When bidding on ad space, increasing bids to show ads to previous visitors.
#         - When selecting which ad to show, using tracking data to pick the ad most relevant to each user.
# - **Benefits of remarketing **
#     - Help people remember your brand
#         - Brand awareness: The more someone is shown your brand, the more likely they are to buy from you when they decide to make a purchase. Use remarketing to drive more traffic to your website and promote your brand.
#     - Find the best message to connect with each user
#         - Tailored messaging: Use remarketing as an opportunity to speak to different segments of your audience. Messaging that works for a first time visitor, likely won’t work as well for a returning visitor who has been to your site many times.
#     - Get more for your money
#         - Lower cost: When you reconnect with people who are already familiar with your service or product, they’re much more likely to click on your ad. So bidding more for a smaller, more targeted audience could end up saving you money.
#     - Increase sales or lead generation
#         - Higher conversion rates: Someone who has seen your product or service before is more likely to purchase than someone who is seeing them for the first time. When you bid on these more qualified leads, you’re more likely to see a return on your investment.

# %% [markdown]
# ### Remarket with the Display Network
# - **How do I get started with Display remarketing?**
#     - Ensure all pages on desktop/mobile site and mobile app are tagged with your remarketing code. Learn how.
#     - All desktop/mobile site or mobile app users will be captured in ‘All Visitors’ (the default remarketing list option) in your AdWords Audiences.
#     - Start creating a remarketing campaign with your ‘All Visitors’ list using the ‘Drive Action’ marketing objective.
#     - You can create additional lists according to your website. A retail company for example, would create five segments: homepage viewers, category viewers, product/item viewers, cart abandoners, converters or equivalent for your vertical.We will be covering lists in the following section.
#     - Tailor the messaging and bidding for each additional segment.
#     - Enable Target CPA or ROAS to automatically adjust bids on users according to their value.
# - **How do I create effective remarketing lists?**
#     - IMAGE: Google_ADs_2
#     - Homepage visitors
#         - They’ve visited your homepage but nothing more -- this is the lightest interaction visitors can have.
#         - Limit your message to what your brand has to offer.
#     - Category pages
#         - They’ve indicated interest in a product category (such as “t-shirts” or “jeans”) but not specific products.
#         - Showcase display ads for specific product categories and speak to special offers or discounts.
#     - Product page
#         - They viewed specific product pages (such as “t-shirts with hearts”) but didn’t add to their shopping cart.
#         - Re-engage them with ads showcasing your “t-shirts with hearts” options.
#     - Cart abandoners
#         - They’ve added products to the shopping cart or started a form, but they left before they finished.
#         - This is your smallest list, but likely your best performing list. Work to bring them back to complete the transaction by offering discounts or special offers.
#     - Past converters
#         - They’ve bought something or taken action on your site before.
#         - You have an opportunity to upsell or cross-sell, speak to other products they be interested in -- let them know what they’re missing.

# %% [markdown]
# ### Choose the most beneficial ad formats
# - **Ad formats that help build awareness**
#     - Responsive ads
#         - Responsive ads adjust to match the pages and apps that show them. Viewers are more likely to see these ads because they blend in with the content the viewers came to see. These ads can do a lot to build awareness, especially when you use viewable cost-per-thousand impressions (vCPM) bidding. This way you can aim broadly without worrying about paying for a lot of impressions that won’t be seen.
#     - Image ads
#         - Image ads are simple static or animated image ads that can be effective at building awareness when used with vCPM bidding. Aim broadly without worrying about paying for a lot of impressions that won’t be seen.
# - **Ad formats that help influence consideration**
#     - Responsive ads
#         - Responsive ads can also be especially helpful in influencing consideration. They automatically adjust their size, appearance, and format to fit available ad spaces.
#     - Image ads
#         - Standard image ads are a great way to influence consideration because they’re enticing to consumers and make engagement easy.
#     - Gmail ads
#         - Gmail ads are expandable ads at the top of tabs in Gmail. They help you reach people with highly targeted, high-impact formats, such as save-to-inbox and forward-to-friends.
#     - Universal app campaigns
#         - Universal app campaigns let you promote your apps across Google’s top properties without having to design individual ads for each ad campaign. You just provide the text, a starting bid, and a budget and Google does the rest. Ads are rotated and adjusted automatically so you get the most downloads for your app.
#     - TrueView ads
#         - TrueView ads (skippable video ads) show on YouTube and can be extended to the web and apps, so you can engage a broader audience with the same video creative. You only pay if someone chooses to watch your ad.
#     - Lightbox ads
#         - Lightbox ads let users engage with a tap that expands to show rich media content such as videos, games, images, maps, or shopping experiences. Build your lightbox once and it runs on every screen and every placement. Lightbox ads are compatible with all targeting methods offered on the Display Network.
# - **Ad formats that help drive action  **
#     - Responsive ads
#         - Can be an effective ally in driving action when you design your ads to start conversions or the purchase process. Viewers are more likely to experience your ads because they feel like a natural part of the site or app, and then your ad can do the work you intended.
#     - Dynamic image ads
#         - Can show viewers ads with products they’ve previously looked at on your site or app. They’re an ideal tool to invite people who have shown interest in the past to complete a purchase.
#     - Display ads
#         - With location extensions can help drive foot traffic to your stores — closing the loop between your online display ads and your offline sales.
#     - Universal app campaigns
#         - Help get more users for your app and find users who are likely to complete in-app actions. AdWords automates targeting and bidding so you can get the best value from each download.
#     - Gmail ads
#         - Are expandable ads at the top of people’s tabs in Gmail. With a click, these interactive ads expand into an email-sized ad that can include videos and images. These ads can be used to meet a variety of advertising goals. Once someone expands your ad, the additional clicks on your content are free.
# - **Three things to remember about ad formats**
#     - Ad formats, like responsive ads, image ads, TrueView ads, universal app campaigns, and Gmail ads, can be used to achieve goals across the funnel. Your messaging and calls to action in your ads will impact the goals that you want to achieve.
#     - The way you bid on an ad format can change the goal that that ad format achieves.
#     - All of the ad formats in this course can run on mobile devices, so you can reach customers while they are on the go across mobile web and in mobile apps.

# %% [markdown]
# ### Set up a Display Network campaign
# - Step 3: Define the campaign
#     - Locations: Linda chooses to target London-based UK customers because she can easily deliver there.
#     - Language: She chooses English because her customers speak English.
#     - Bid strategy: Viewable cost per thousand (vCPM) has already been selected because its best suited for building awareness.
#     - Budget: Linda enters 100 per day.
#     - Linda clicks Save and continue.
# - https://academy.exceedlms.com/uploads/resource_courses/targets/11051/original/index.html#/id/57a097570b273f5c5ad71e8d

# %% [markdown]
# ### Assess and optimize your campaigns
# - **How to improve your results with performance data**
#     - You can use the data AdWords collects while your campaign is running to see what's getting results.
# - **Display performance metrics for driving action**
#     - How effective are your Display ads at driving action? You can see for yourself in AdWords by looking at a combination of conversions, view-through conversions, and conversion delays. If your ad views and clicks aren’t leading to results, it may be time to refresh your ads, targeting, landing page, or all three. If your goal is conversions you should use target cost-per-acquisition (CPA) bidding to get more conversions for your budget. Let’s take a closer look at these metrics, and at target CPA bidding.
#     - Conversions:
#         - How many customers converted after clicking on your ad? Conversions show you how well your ads and site are working together to drive action. (Just ensure conversion tracking is on in AdWords so you can see this data.)
#     - Target cost per acquisition (CPA)
#         - How much do you want to spend for each conversion? Cost per acquisition is the average amount you pay for a conversion. If your goal is to get the most conversions for your budget, you should use an automated bid strategy based on your target CPA. It’s recommended that you use a 30-day historical CPA.
#     - View-through conversions (VTCs)
#         - How many customers could see your ad and converted on your site without clicking the ad? A VTC is triggered whenever a user is on the Display Network and sees your ad, but does not click on it. The user later directly visits your website or finds it via an organic search or other referring site (basically any source other than Google/AdWords).
# - **Display metrics for brand awareness **
#     - How effective are your Display ads at driving action? You can see for yourself in AdWords by looking at a combination of conversions, view-through conversions, and conversion delays. If your ad views and clicks aren’t leading to results, it may be time to refresh your ads, targeting, landing page, or all three. If your goal is conversions you should use target cost-per-acquisition (CPA) bidding to get more conversions for your budget. Let’s take a closer look at these metrics, and at target CPA bidding.
#     - Reach: Ad reach is an estimate of the number of people who see your ad. It’s a great metric for measuring how well you’re doing against your goal of building brand awareness.
#     - Frequency: Frequency is an estimate of the average number of times a unique cookie was exposed to your ad over a given time period.
# - **Improve target audience results**
#     - Your AdWords Display campaigns show targeting performance for each of your targeting methods (Keywords, Audiences, Demographics, Topics, Placements). Identify the targeting methods that perform best based on your goals and update to replace poor performers with proven performers.
# - **How to troubleshoot Display campaigns**
#     - If a Display campaign encounters issues, AdWords provides notifications in “Status review”. To get his ads up and running, Sam will want to address these issues and make any necessary corrections. Let’s take a look at how Sam handles some of these notifications.
#     - Ads not serving:
#         - His targeting is too restrictive for ads to serve
#         - His ads aren’t running because some of them have been disapproved
#         - His bids are too low for his ads to run
#     - Incompatible targeting
#         - Gmail ads aren't compatible with custom affinity audiences, remarketing, and remarketing-based similar audiences
#         - Gmail ads are compatible with Customer Match, but they can only run on mail.google.com
#     - Remarketing tags and feeds
#         - For tagging: the tag activity has dropped or the tag has errors in the HTML code
#         - For feeds: the items in the feed have been disapproved
# - **Optimize for success: responsive ads**
#     - Sam wants his ads to appear wherever they can across the Display Network, wherever ad space is available. Unfortunately, he doesn’t have the the design team to be able to deliver creatives in a variety of sizes and formats on-demand. Instead of hiring a huge team, Sam can simply create responsive ads. Let’s follow along as he creates his first one.
# - **Optimize for success: automated bidding**
#     - Target cost per acquisition (CPA) automatically sets Display bids to help get as many conversions as possible at the target CPA Sam sets.
#     - If Sam wants to automate while still maintaining control over the cost-per-click (CPC) bids, he can use Enhanced cost per click (ECPC) to automatically adjust his manual bids. This helps him get 10 percent more conversions on average, while trying to achieve the same cost per conversion as he got on Manual CPC.
#     - If Sam values his various conversions at different rates, he can use Target ROAS to automatically set bids to get as much conversion value as possible at the target ROAS he sets. He’ll need to import his conversion values in order to use it.
#     - Maximize Clicks automatically sets bids to help Sam get as many clicks as possible within his budget.
# - Targeting optimization works best for advertisers looking to:
#     - Find more customers
#     - Identify the best targeting to reach their most likely customers
#     - Increase reach without increasing bids or cost per customer
# -  Conservative automatic targeting applies a lightweight expansion that’s similar to his existing targeting. Aggressive automatic targeting applies a much broader expansion in order to explore additional inventory. Both types can help him reach additional customers, but aggressive targeting brings Sam more customers at a slightly higher CPA.
# - Sam would choose conservative targeting when he wants more conversions, but needs to stay close to his current cost per customer (or target CPA). This would be the better option if he had a fixed or limited budget.
# - He would choose aggressive targeting when he wants to get as many conversions as possible and is comfortable with some variation from his current cost per customer (or target CPA/ROAS).
# - Sam also has the option to use highly automated Smart display campaigns, which use yet another type of automated targeting, combining contextual and audience-based targeting. They also automatically remarket to people who've recently visited his site and who are likely to convert.

# %% [markdown]
# - CTR is the number of clicks that your ad receives divided by the number of times your ad is shown: clicks ÷ impressions = CTR. For example, if you had 5 clicks and 1000 impressions, then your CTR would be 0.5%.
