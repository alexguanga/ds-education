# %%
import numpy
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
from patsy import dmatrices

# %% [markdown]
# ** NOTES ON PROJECT**
# - You prediction should be 78% accurate or higher.
#
# - Here's a simple heuristic to start off:
#    1. If the passenger is female, your heuristic should assume that the
#    passenger survived.
#    2. If the passenger is male, you heuristic should
#    assume that the passenger did not survive.
#
# - You can access the gender of a passenger via passenger['Sex'].
#      - If the passenger is male, passenger['Sex'] will return a string "male".
#      - If the passenger is female, passenger['Sex'] will return a string "female".
#
# - For example, if a passenger is predicted to have survived:
#      - passenger_id = passenger['PassengerId']
#      - predictions[passenger_id] = 1
#
# - And if a passenger is predicted to have perished in the disaster:
#      - passenger_id = passenger['PassengerId']
#      - predictions[passenger_id] = 0
#
# - You can also look at the Titantic data that you will be working with at the link below:
#      - https://s3.amazonaws.com/content.udacity-data.com/courses/ud359/titanic_data.csv

# %%
from fnmatch import fnmatch, fnmatchcase
 
def create_title(df):
    title = []
    for passenger_index, passenger in df.iterrows():
        name = passenger['Name']

        if (name.find('Miss.') > 0):
            print('Miss', name.find('Miss.'))
        elif (name.find('Master.') > 0):
            print('Master.', name.find('Master.'), name)
        elif (name.find('Mrs.') > 0):
            print('Mr.', name.find('Mrs.'), name)
        elif (name.startswith('Mr.') > 0):
            df['Title'] = 'Mr.'
        else:
            df['Title'] = 'Other'

# %%
import numpy
import pandas
import statsmodels.api as sm

def custom_heuristic(file_path):
    predictions = {}
    df = pandas.read_csv(file_path)
    
    create_title(df)
    
    for passenger_index, passenger in df.iterrows():
        passenger_id = passenger['PassengerId']
        
    
    
    #return predictions

custom_heuristic('train.csv')
# Out:
# Miss 11
# Master. -1 Palsson, Master. Gosta Leonard
# Miss 11
# Miss 9
# Miss 9
# Master. -1 Rice, Master. Eugene
# Miss 9
# Miss 9
# Miss 9
# Miss 7
# Miss 15
# Miss 15
# Miss 9
# Miss 9
# Miss 12
# Master. -1 Panula, Master. Juha Niilo
# Miss 6
# Miss 6
# Master. -1 Goodwin, Master. William Frederick
# Miss 7
# Master. -1 Skoog, Master. Harald
# Master. -1 Moubarek, Master. Gerios
# Miss 11
# Miss 9
# Master. -1 Caldwell, Master. Alden Gates
# Miss 9
# Miss 11
# Miss 7
# Miss 9
# Miss 10
# Miss 13
# Miss 7
# Miss 8
# Miss 9
# Miss 9
# Miss 11
# Miss 8
# Master. -1 Nicola-Yarred, Master. Elias
# Miss 7
# Miss 8
# Miss 8
# Miss 6
# Miss 9
# Master. -1 Sage, Master. Thomas Henry
# Master. -1 Panula, Master. Eino Viljami
# Master. -1 Goldsmith, Master. Frank John William "Frankie"
# Master. -1 Rice, Master. Arthur
# Miss 9
# Master. -1 Lefebre, Master. Henry Forbes
# Miss 7
# Miss 6
# Master. -1 Asplund, Master. Clarence Gustaf Hugo
# Master. -1 Becker, Master. Richard F
# Miss 15
# Miss 17
# Master. -1 Navratil, Master. Michel M
# Miss 9
# Miss 9
# Miss 7
# Miss 7
# Miss 6
# Miss 9
# Miss 8
# Miss 10
# Miss 9
# Miss 9
# Miss 9
# Miss 10
# Miss 9
# Miss 8
# Miss 8
# Miss 9
# Miss 8
# Miss 6
# Master. -1 Asplund, Master. Edvin Rojj Felix
# Miss 7
# Miss 10
# Miss 7
# Miss 9
# Miss 10
# Master. -1 Rice, Master. Eric
# Miss 10
# Miss 8
# Miss 6
# Miss 9
# Miss 7
# Miss 7
# Master. -1 Allison, Master. Hudson Trevor
# Miss 9
# Miss 13
# Miss 6
# Miss 9
# Miss 9
# Miss 6
# Miss 9
# Miss 7
# Miss 9
# Miss 7
# Miss 7
# Master. -1 Navratil, Master. Edmond Roger
# Miss 9
# Miss 7
# Miss 7
# Master. -1 Coutts, Master. William Loch "William"
# Miss 10
# Miss 6
# Miss 10
# Miss 9
# Miss 8
# Miss 9
# Miss 12
# Miss 8
# Miss 7
# Master. -1 Goodwin, Master. Sidney Leonard
# Miss 6
# Miss 9
# Miss 8
# Miss 8
# Miss 9
# Miss 11
# Master. -1 Richards, Master. William Rowe
# Miss 9
# Miss 9
# Miss 8
# Miss 10
# Miss 10
# Miss 8
# Miss 6
# Master. -1 Dodge, Master. Washington
# Miss 11
# Miss 9
# Miss 8
# Miss 9
# Miss 12
# Miss 10
# Master. -1 Goodwin, Master. Harold Victor
# Miss 9
# Master. -1 Coutts, Master. Eden Leslie "Neville"
# Miss 8
# Miss 9
# Miss 12
# Miss 10
# Miss 8
# Miss 11
# Miss 10
# Miss 7
# Miss 7
# Miss 6
# Miss 7
# Miss 11
# Miss 8
# Miss 11
# Miss 11
# Master. -1 Davies, Master. John Morgan Jr
# Miss 7
# Miss 10
# Miss 7
# Miss 9
# Miss 9
# Miss 9
# Miss 8
# Miss 8
# Miss 8
# Miss 8
# Miss 8
# Miss 8
# Miss 9
# Miss 7
# Miss 7
# Miss 7
# Miss 9
# Miss 9
# Miss 8
# Miss 9
# Miss 9
# Miss 7
# Miss 8
# Miss 8
# Miss 7
# Miss 9
# Miss 9
# Miss 9
# Master. -1 Moubarek, Master. Halim Gonios ("William George")
# Miss 8
# Miss 8
# Miss 8
# Miss 9
# Miss 12
# Miss 7
# Miss 9
# Miss 11
# Miss 7
# Master. -1 Moor, Master. Meier
# Master. -1 Hamalainen, Master. Viljo
# Miss 8
# Miss 9
# Miss 7
# Miss 9
# Master. -1 Rice, Master. George Hugh
# Master. -1 Dean, Master. Bertram Vere
# Miss 6
# Master. -1 Carter, Master. William Thornton II
# Master. -1 Thomas, Master. Assad Alexander
# Miss 12
# Miss 11
# Miss 10
# Master. -1 Skoog, Master. Karl Thorsten
# Master. -1 Panula, Master. Urho Abraham
# Master. -1 Mallet, Master. Andre
# Master. -1 Richards, Master. George Sibley
# Miss 9
# Miss 10
# Master. -1 Andersson, Master. Sigvard Harald Elias
# Miss 8
# Miss 7
# Miss 6
# Miss 14
# Master. -1 Johnson, Master. Harold Theodor
# Miss 7
# Miss 10
# Miss 8
# Miss 10
