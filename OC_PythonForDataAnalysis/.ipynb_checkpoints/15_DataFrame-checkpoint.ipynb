# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser

website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.582              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
# columns of the pandas
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
# Getting the information from specific columns
nfl_frame.Team
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# Name: Team, dtype: object

# %%
nfl_frame['First NFL Season']
# Out:
# 0    1960
# 1    1921
# 2    1920
# 3    1966
# 4    1960
# Name: First NFL Season, dtype: int64

# %%
# Using columns from the dataframe
DataFrame(nfl_frame, columns=['Team', 'Tied', 'Pct.'])
# Out:
#                       Team  Tied   Pct.
# 0           Dallas Cowboys     1  0.582
# 1        Green Bay Packers    37  0.567
# 2            Chicago Bears    42  0.565
# 3           Miami Dolphins     4  0.563
# 4  New England Patriots[b]     9  0.554

# %%
# Using columns form the dataframe with a col. not listed in the dataframe
DataFrame(nfl_frame, columns=['Team', 'Tied', 'Pct.', 'Stadium'])
# Out:
#                       Team  Tied   Pct.  Stadium
# 0           Dallas Cowboys     1  0.582      NaN
# 1        Green Bay Packers    37  0.567      NaN
# 2            Chicago Bears    42  0.565      NaN
# 3           Miami Dolphins     4  0.563      NaN
# 4  New England Patriots[b]     9  0.554      NaN

# %%
# A view of the first 5 rows
nfl_frame.head()
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.582              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
# A view of the last 5 rows
nfl_frame.tail()
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.582              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
# ix changed to iloc
nfl_frame.iloc[3]
# Out:
# Rank                             4
# Team                Miami Dolphins
# Won                            439
# Lost                           341
# Tied                             4
# Pct.                         0.563
# First NFL Season              1966
# Total Games                    784
# Division                  AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Alex's Stadium"
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.582              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division         Stadium
# 0         860   NFC East  Alex's Stadium
# 1       1,320  NFC North  Alex's Stadium
# 2       1,354  NFC North  Alex's Stadium
# 3         784   AFC East  Alex's Stadium
# 4         868   AFC East  Alex's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.582              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division  Stadium
# 0         860   NFC East        0
# 1       1,320  NFC North        1
# 2       1,354  NFC North        2
# 3         784   AFC East        3
# 4         868   AFC East        4

# %%
stadiums = Series(['Alex Stadium', 'ATT Stadium'], index=[4,0])
stadiums
# Out:
# 4    Alex Stadium
# 0     ATT Stadium
# dtype: object

# %%
# If we want to the stadiums assigned in the code above into the dataframe...
nfl_frame['Stadium'] = stadiums
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.582              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division       Stadium
# 0         860   NFC East   ATT Stadium
# 1       1,320  NFC North           NaN
# 2       1,354  NFC North           NaN
# 3         784   AFC East           NaN
# 4         868   AFC East  Alex Stadium

# %%
# delete column
del nfl_frame['Stadium']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/alexguanga/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'Stadium'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-f4a0b14e2260> in <module>()
#       1 # delete column
# ----> 2 del nfl_frame['Stadium']
#
# /Users/alexguanga/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    1899             # there was no match, this call should raise the appropriate
#    1900             # exception:
# -> 1901             self._data.delete(key)
#    1902
#    1903         # delete from the caches
#
# /Users/alexguanga/anaconda/lib/python3.6/site-packages/pandas/core/internals.py in delete(self, item)
#    3647         Delete selected item (items if non-unique) in-place.
#    3648         """
# -> 3649         indexer = self.items.get_loc(item)
#    3650
#    3651         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# /Users/alexguanga/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'Stadium'

# %%
nfl_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.582              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
data = {'City': ['LA', 'SF', 'NY'], 'Population': [3880000,837000,8400000]}

# %%
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   LA     3880000
# 1   SF      837000
# 2   NY     8400000
